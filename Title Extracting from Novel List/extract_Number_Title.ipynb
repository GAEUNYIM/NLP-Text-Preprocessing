# %%
# 기존의 파일 이름 목록에서 작품 번호와 작품 제목만을 추출하는 코드
# txt파일 형태로 저장

# 추출 전 : 73. 영자의 전성시대 / 조선작(趙善作)
# 추출 후 : 73. 영자의 전성시대

root_path = "C:/Users/rkdms/OneDrive_UNIST/바탕 화면/UNIST/2021_01/[DH Lab] 현대소설111/"
row_novel_list = open(root_path + 'row_novel_list.txt', 'r')
spl_file_list = open(root_path + 'spl_file_list.txt', 'w')

while True:
    line = row_novel_list.readline()
    if not line:
        break
    print(line)
    
    title = line.split(' /')[0].split('(')[0]
    
    spl_file_list.write(title + '\n')
   
    
row_novel_list.close()
spl_file_list.close()
# Out:
# 1. 젊은 느티나무 / 강신재
#
# 2. 백치 아다다 / 계용묵
#
# 3. 카프카를 읽는 밤 / 구효서
#
# 4. 강아지 똥 / 권정생
#
# 5. 등신불(等身佛) / 김동리
#
# 6. 바위 / 김동리
#
# 7. 역마(驛馬) / 김동리
#
# 8. 감자 / 김동인
#
# 9. 광화사 / 김동인
#
# 10. 발가락이 닮았다 / 김동인
#
# 11. 배따라기 / 김동인
#
# 12. 바비도 / 김성한
#
# 13. 암야행 / 김성한
#
# 14. 오분간 / 김성한
#
# 15. 무진기행 / 김승옥
#
# 16. 서울, 1964년, 겨울 / 김승옥
#
# 17. 어둠의 혼(魂) / 김원일
#
# 18. 연 / 김원일
#
# 19. 金 따는 콩밭 / 김유정
#
# 20. 동백꽃 / 김유정
#
# 21. 만무방 / 김유정
#
# 22. 봄 봄 / 김유정
#
# 23. 소낙비 / 김유정
#
# 24. 사하촌(寺下村) / 김정한
#
# 25. 물레방아 / 나도향
#
# 26. 불신 시대 / 박경리
#
# 27. 샤갈의 마을에 내리는 눈 / 박상우
#
# 28. 유서 / 박성원
#
# 29. 모범 경작생(模範耕作生) / 박영준
#
# 30. 겨울 나들이 / 박완서(朴婉緖)
#
# 31. 꿈꾸는 인큐베이터 / 박완서
#
# 32. 옥상의 민들레꽃 / 박완서
#
# 33. 우황청심환 / 박완서
#
# 34. 아랑의 정조 / 박종화
#
# 35. 강(江) / 서정인(徐廷仁)
#
# 36. 아름다운 얼굴 / 송기원
#
# 37. 월행(月行) / 송기원
#
# 38. 쑈리 킴 / 송병수
#
# 39. 빈집 / 신경숙
#
# 40. 풍금이 있던 자리 / 신경숙
#
# 41. 비오는 날이면 가리봉동에 가야 한다 / 양귀자
#
# 42. 화산댁이 / 오영수(吳永壽)
#
# 43. 후조(候鳥) / 오영수
#
# 44. 동경(銅鏡) / 오정희(吳貞姬)
#
# 45. 中國人 거리 / 오정희
#
# 46. 김강사(金講師)와 T교수(敎授) / 유진오(兪鎭午)
#
# ...
